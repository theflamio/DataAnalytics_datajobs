# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = r'C:\Dev\DataAnalytics_datajobs\TestScripts\kaggle'

import json

from kaggle.api.kaggle_api_extended import KaggleApi

# Instantiate the Kaggle API
api = KaggleApi()

# Authenticate with your Kaggle API credentials
api.authenticate()

# Specify the dataset you want to download
dataset_name = 'lukebarousse/data-analyst-job-postings-google-search'
owner_slug, dataset_slug = dataset_name.split('/')

# Define the directory to save the dataset
save_dir = '../data'

# Create the directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Check if the dataset version file exists
version_file_path = os.path.join(save_dir, 'dataset_version.json')

if os.path.exists(version_file_path):
    # Load the current dataset version
    with open(version_file_path, 'r') as version_file:
        current_version_data = json.load(version_file)
    current_version = current_version_data.get('version')
else:
    current_version = None

# Get dataset creation status
dataset_creation_status = api.dataset_view(owner_slug, dataset_slug)

print("dataset_creation_status:", dataset_creation_status)

# Extract creation date from the response
creation_date = dataset_creation_status['creationDate']

# Print the creation date
print("Dataset Creation Date:", creation_date)

dataset_version = dataset_metadata['currentVersionNumber']

# Check if the dataset has a newer version
if current_version != dataset_version:
    # Download the dataset
    api.dataset_download_files(dataset_name, path=save_dir, unzip=True)
    
    # Save the dataset version
    with open(version_file_path, 'w') as version_file:
        json.dump({'version': dataset_version}, version_file)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [1], in <module>
#      35     current_version = None
#      37 # Get dataset creation status
# ---> 38 dataset_creation_status = api.datasets_status_with_http_info(owner_slug, dataset_slug)
#      40 print("dataset_creation_status:", dataset_creation_status)
#      42 # Extract creation date from the response
#
# File c:\Users\flame\AppData\Local\Programs\Python\Python310\lib\site-packages\kaggle\api\kaggle_api.py:1995, in KaggleApi.datasets_status_with_http_info(self, owner_slug, dataset_slug, **kwargs)
#    1992 # Authentication setting
#    1993 auth_settings = ['basicAuth']  # noqa: E501
# -> 1995 return self.api_client.call_api(
#    1996     '/datasets/status/{ownerSlug}/{datasetSlug}', 'GET',
#    1997     path_params,
#    1998     query_params,
#    1999     header_params,
#    2000     body=body_params,
# ...
